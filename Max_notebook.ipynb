# %%
import pandas as pd
import numpy as np
import pickle
import pandas
from scipy.io import readsav
import pyreadstat

# %%
filepath_historical_data = '/Users/maxburger/code/MadMax1995bb/powder_alert2.0/raw_data/Hochfuegen_historyDS.csv'

# %%
filepath_v2 = '/Users/maxburger/code/MadMax1995bb/powder_alert2.0/raw_data/Alternative_data_v2.csv'
filepath_v3 = '/Users/maxburger/code/MadMax1995bb/powder_alert2.0/raw_data/Alternative_data_v3_Davos.csv'

# %%
csv_file = filepath_historical_data
df = pd.read_csv(csv_file)
df.tail(3)
# Out:
#                 dt                         dt_iso  timezone  city_name  \
# 402858  1733691600  2024-12-08 21:00:00 +0000 UTC      3600  Hochfügen
# 402859  1733695200  2024-12-08 22:00:00 +0000 UTC      3600  Hochfügen
# 402860  1733698800  2024-12-08 23:00:00 +0000 UTC      3600  Hochfügen
#
#              lat       lon    temp  visibility  dew_point  feels_like  ...  \
# 402858  47.26759  11.77616  269.18         NaN     268.70      264.98  ...
# 402859  47.26759  11.77616  268.57         NaN     268.09      264.25  ...
# 402860  47.26759  11.77616  268.16         NaN     267.68      263.70  ...
#
#         wind_gust  rain_1h  rain_3h  snow_1h  snow_3h  clouds_all  weather_id  \
# 402858       3.04      NaN      NaN      NaN      0.5         100         600
# 402859       3.04      NaN      NaN      NaN      0.5         100         600
# 402860       3.12      NaN      NaN      NaN      1.0         100         600
#
#         weather_main  weather_description  weather_icon
# ...

# %%
csv_file = filepath_v2
df = pd.read_csv(csv_file)
df.tail(3)
# Out:
#         Unnamed: 0       datum station_code  sector_id  warnreg  \
# 292834      292834  2020-05-04         SHE2     1213.0     21.0
# 292835      292835  2020-05-04         ELS2     1231.0     21.0
# 292836      292836  2020-05-04         LAU2     1222.0     21.0
#
#         elevation_station forecast_initial_date    forecast_end_date  \
# 292834             1900.0   2020-05-04 17:00:00  2020-05-05 17:00:00
# 292835             2100.0   2020-05-04 17:00:00  2020-05-05 17:00:00
# 292836             2000.0   2020-05-04 17:00:00  2020-05-05 17:00:00
#
#         dangerLevel  elevation_th  ... ssi_pwl  sk38_pwl  sn38_pwl  ccl_pwl  \
# 292834          2.0        1800.0  ...     NaN       NaN       NaN      NaN
# 292835          2.0        1800.0  ...     NaN       NaN       NaN      NaN
# 292836          2.0        1800.0  ...     NaN       NaN       NaN      NaN
#
#         ssi_pwl_100  sk38_pwl_100  sn38_pwl_100  ccl_pwl_100  Pen_depth  \
# ...

# %%
csv_file = filepath_v3
df = pd.read_csv(csv_file, delimiter=';')
df.tail(3)
# Out:
#           no date_release snow_type trigger_type  max_elevation_m  \
# 13915  13916   2019-05-07       dry        HUMAN           2589.0
# 13916  13917   2019-05-07       wet        HUMAN           2572.0
# 13917  13918   2019-05-27       wet      NATURAL           2559.0
#
#        min_elevation_m  aspect_degrees  length_m  width_m  perimeter_length_m  \
# 13915           2567.0           307.0      36.0     14.0                82.0
# 13916           2532.0            80.0      65.0     25.0               150.0
# 13917           2524.0            80.0      56.0     42.0               156.0
#
#        area_m2  aval_size_class  weight_AAI  max.danger.corr
# 13915    340.0                1        0.01              2.0
# 13916   1044.0                2        0.10              2.0
# 13917   1308.0                2        0.10              NaN
